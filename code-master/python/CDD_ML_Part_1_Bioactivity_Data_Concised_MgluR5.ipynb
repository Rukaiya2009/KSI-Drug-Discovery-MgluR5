# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/python/3.10.13/lib/python3.10/site-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /home/codespace/.local/lib/python3.10/site-packages (from chembl_webresource_client) (2.31.0)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from chembl_webresource_client) (1.2.0)
# Requirement already satisfied: easydict in /usr/local/python/3.10.13/lib/python3.10/site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /home/codespace/.local/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.0)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.10.0)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('MgluR5')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P41594', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'P31424', 'xref_name': None, 'xre...  Rattus norvegicus
# 2  [{'xref_id': 'NBK23687', 'xref_name': 'Metabot...       Mus musculus
# 3                                                 []       Homo sapiens
# 4                                                 []  Rattus norvegicus
#
#                                            pref_name  score  \
# 0                  Metabotropic glutamate receptor 5   20.0
# 1                  Metabotropic glutamate receptor 5   20.0
# 2                  Metabotropic glutamate receptor 5   20.0
# 3  D(2) dopamine receptor/Metabotropic glutamate ...   18.0
# 4                    Metabotropic glutamate receptor   11.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL3227
# 1               False       CHEMBL2564
# 2               False    CHEMBL1641352
# 3               False    CHEMBL4296096
# 4               False    CHEMBL2111335
#
#                                    target_components      target_type  tax_id
# 0  [{'accession': 'P41594', 'component_descriptio...   SINGLE PROTEIN    9606
# 1  [{'accession': 'P31424', 'component_descriptio...   SINGLE PROTEIN   10116
# 2  [{'accession': 'Q3UVX5', 'component_descriptio...   SINGLE PROTEIN   10090
# 3  [{'accession': 'P14416', 'component_descriptio...  PROTEIN COMPLEX    9606
# 4  [{'accession': 'P31424', 'component_descriptio...   PROTEIN FAMILY   10116

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3227'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       489503                  []
# 1        None             None       489504                  []
# 2        None             None       496491                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL715727  In vitro for inhibitory activity of compound a...
# 1    CHEMBL711710  Tested in vitro binding affinity for displacem...
# 2    CHEMBL715727  In vitro for inhibitory activity of compound a...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          F                    None                   None  BAO_0000190  ...
#
#   target_organism                   target_pref_name target_tax_id text_value  \
# 0    Homo sapiens  Metabotropic glutamate receptor 5          9606       None
# 1    Homo sapiens  Metabotropic glutamate receptor 5          9606       None
# 2    Homo sapiens  Metabotropic glutamate receptor 5          9606       None
#
#    toid  type units    uo_units upper_value   value
# 0  None  IC50    nM  UO_0000065        None    36.0
# 1  None  IC50    nM  UO_0000065        None    20.0
# 2  None  IC50    nM  UO_0000065        None  3000.0
#
# [3 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('MgluR5_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#      action_type activity_comment  activity_id  \
# 0           None             None       489503
# 1           None             None       489504
# 2           None             None       496491
# 3           None             None       496492
# 4           None             None       508727
# ...          ...              ...          ...
# 2205        None             None     19409479
# 2206        None             None     19477064
# 2207        None             None     22409325
# 2208        None             None     22842011
# 2209        None             None     22926099
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL715727
# 1                                                    []    CHEMBL711710
# 2                                                    []    CHEMBL715727
# 3                                                    []    CHEMBL711710
# 4                                                    []    CHEMBL715727
# ...                                                 ...             ...
# 2205                                                 []   CHEMBL4427245
# 2206                                                 []   CHEMBL4479800
# 2207                                                 []   CHEMBL4671165
# 2208  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4719966
# 2209                                                 []   CHEMBL4737556
#
#                                       assay_description assay_type  \
# 0     In vitro for inhibitory activity of compound a...          F
# 1     Tested in vitro binding affinity for displacem...          B
# 2     In vitro for inhibitory activity of compound a...          F
# 3     Tested in vitro binding affinity for displacem...          B
# 4     In vitro for inhibitory activity of compound a...          F
# ...                                                 ...        ...
# 2205  Negative allosteric modulation of human recomb...          F
# 2206  Negative allosteric modulation of human mGluR5...          F
# 2207  Negative allosteric modulation of mGlu5 recept...          B
# 2208  Antagonist activity at human recombinant mGlu5...          F
# 2209         Binding affinity to mGlu5 (unknown origin)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 2205                    None                   None  BAO_0000190  ...
# 2206                    None                   None  BAO_0000190  ...
# 2207                    None                   None  BAO_0000190  ...
# 2208                    None                   None  BAO_0000190  ...
# 2209                    None                   None  BAO_0000190  ...
#
#      target_organism                   target_pref_name target_tax_id  \
# 0       Homo sapiens  Metabotropic glutamate receptor 5          9606
# 1       Homo sapiens  Metabotropic glutamate receptor 5          9606
# 2       Homo sapiens  Metabotropic glutamate receptor 5          9606
# 3       Homo sapiens  Metabotropic glutamate receptor 5          9606
# 4       Homo sapiens  Metabotropic glutamate receptor 5          9606
# ...              ...                                ...           ...
# 2205    Homo sapiens  Metabotropic glutamate receptor 5          9606
# 2206    Homo sapiens  Metabotropic glutamate receptor 5          9606
# 2207    Homo sapiens  Metabotropic glutamate receptor 5          9606
# 2208    Homo sapiens  Metabotropic glutamate receptor 5          9606
# 2209    Homo sapiens  Metabotropic glutamate receptor 5          9606
#
#      text_value  toid  type units    uo_units upper_value    value
# 0          None  None  IC50    nM  UO_0000065        None     36.0
# 1          None  None  IC50    nM  UO_0000065        None     20.0
# 2          None  None  IC50    nM  UO_0000065        None   3000.0
# 3          None  None  IC50    nM  UO_0000065        None   1100.0
# 4          None  None  IC50    nM  UO_0000065        None     10.0
# ...         ...   ...   ...   ...         ...         ...      ...
# 2205       None  None  IC50    nM  UO_0000065        None    477.0
# 2206       None  None  IC50    nM  UO_0000065        None     27.0
# 2207       None  None  IC50    uM  UO_0000065        None     30.0
# 2208       None  None  IC50    nM  UO_0000065        None  12500.0
# 2209       None  None  IC50    uM  UO_0000065        None     10.0
#
# [2107 rows x 46 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  #else:
  #  bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL66654                             Cc1cccc(C#Cc2ccccc2)n1
# 1           CHEMBL66654                             Cc1cccc(C#Cc2ccccc2)n1
# 2           CHEMBL88612                           Cc1cccc(/C=C/c2ccccc2)n1
# 3           CHEMBL88612                           Cc1cccc(/C=C/c2ccccc2)n1
# 4         CHEMBL2112677        [3H]C([3H])([3H])OCc1cccc(C#Cc2cccc(C)n2)c1
# ...                 ...                                                ...
# 2205      CHEMBL4591221       CC(C)(C)c1cc2n(n1)CCN(C(=O)c1ccc3ccccc3c1)C2
# 2206      CHEMBL4572894  O=C1N[C@H](c2cncc(C#Cc3ccccc3)c2)[C@@H](c2c(F)...
# 2207      CHEMBL1527295      CCOC(=O)c1cnc2c(OC)cccc2c1N1CCN(c2ccccc2F)CC1
# 2208      CHEMBL4751065  Cl.N[C@]1(C(=O)O)[C@@H]2[C@@H](C(=O)O)[C@@H]2[...
# 2209      CHEMBL4758183           O=C1CCSC[C@@H](C(=O)Nc2cc(Cl)cc(Br)c2)N1
#
#      standard_value
# 0              36.0
# 1              20.0
# 2            3000.0
# 3            1100.0
# 4              10.0
# ...             ...
# 2205          477.0
# 2206           27.0
# 2207        30000.0
# 2208        12500.0
# 2209        10000.0
#
# [2107 rows x 3 columns]

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#      molecule_chembl_id                             canonical_smiles  \
# 0           CHEMBL66654                       Cc1cccc(C#Cc2ccccc2)n1
# 1           CHEMBL66654                       Cc1cccc(C#Cc2ccccc2)n1
# 2           CHEMBL88612                     Cc1cccc(/C=C/c2ccccc2)n1
# 3           CHEMBL88612                     Cc1cccc(/C=C/c2ccccc2)n1
# 4         CHEMBL2112677  [3H]C([3H])([3H])OCc1cccc(C#Cc2cccc(C)n2)c1
# ...                 ...                                          ...
# 1576                NaN                                          NaN
# 1577                NaN                                          NaN
# 1578                NaN                                          NaN
# 1579                NaN                                          NaN
# 1580                NaN                                          NaN
#
#      standard_value bioactivity_class
# 0              36.0            active
# 1              20.0            active
# 2            3000.0            active
# 3            1100.0            active
# 4              10.0          inactive
# ...             ...               ...
# 1576            NaN            active
# 1577            NaN            active
# 1578            NaN            active
# 1579            NaN            active
# 1580            NaN            active
#
# [2210 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df4.to_csv('MgluR5_bioactivity_data_preprocessed.csv', index=False)

# %%
! ls -l
# Out:
# total 16792
# -rw-rw-rw-  1 codespace codespace   70569 Apr 24 13:18 CDD_ML_Part_1_Bioactivity_Data_Concised.ipynb
# -rw-rw-rw-  1 codespace root        60854 Apr 24 14:38 CDD_ML_Part_1_Bioactivity_Data_Concised_MgluR5.ipynb
# -rw-rw-rw-  1 codespace root       124747 Apr 24 13:07 CDD_ML_Part_1_MgluR5_Bioactivity_Data_Concised.ipynb
# -rw-rw-rw-  1 codespace root        85900 Apr 24 13:07 CDD_ML_Part_1_MgluR5_bioactivity_data.ipynb
# -rw-rw-rw-  1 codespace root       313244 Apr 24 13:07 CDD_ML_Part_2_Acetylcholinesterase_Exploratory_Data_Analysis.ipynb
# -rw-rw-rw-  1 codespace root       226308 Apr 24 13:07 CDD_ML_Part_2_Exploratory_Data_Analysis.ipynb
# -rw-rw-rw-  1 codespace root       208719 Apr 24 13:07 CDD_ML_Part_3_Acetylcholinesterase_Descriptor_Dataset_Preparation.ipynb
# -rw-rw-rw-  1 codespace root       100076 Apr 24 13:07 CDD_ML_Part_4_Acetylcholinesterase_Regression_Random_Forest.ipynb
# -rw-rw-rw-  1 codespace root       230778 Apr 24 13:07 CDD_ML_Part_5_Acetylcholinesterase_Compare_Regressors.ipynb
# -rw-rw-rw-  1 codespace root        36193 Apr 24 13:07 Colab_File_handling_on_Google_Colab.ipynb
# -rw-rw-rw-  1 codespace root       166833 Apr 24 13:07 How_to_build_a_simple_linear_regression_model_in_python.ipynb
# -rw-rw-rw-  1 codespace root        11473 Apr 24 13:07 Hummingbird_ML.ipynb
# -rw-rw-rw-  1 codespace codespace  144017 Apr 24 14:38 MgluR5_bioactivity_data_preprocessed.csv
# -rw-rw-rw-  1 codespace codespace 1265679 Apr 24 14:35 MgluR5_bioactivity_data_raw.csv
# -rw-rw-rw-  1 codespace root       125948 Apr 24 13:07 PCA_analysis.ipynb
# -rw-rw-rw-  1 codespace root        43007 Apr 24 13:07 ROC_curve.ipynb
# -rw-rw-rw-  1 codespace root        59298 Apr 24 13:07 ROC_curve_kNN.ipynb
# -rw-rw-rw-  1 codespace root      1894229 Apr 24 13:07 Sweetviz.ipynb
# -rw-rw-rw-  1 codespace root       308736 Apr 24 13:07 cheminformatics_predicting_solubility.ipynb
# -rw-rw-rw-  1 codespace root        62769 Apr 24 13:07 cheminformatics_predicting_solubility_2_1_PyCaret.ipynb
# -rw-rw-rw-  1 codespace root      1101744 Apr 24 13:07 cheminformatics_predicting_solubility_2_2_PyCaret.ipynb
# -rw-rw-rw-  1 codespace root        47794 Apr 24 13:07 comparing-classifiers.ipynb
# -rw-rw-rw-  1 codespace root         2408 Apr 24 13:07 credentials-420719-9413d70d773c.json
# -rw-rw-rw-  1 codespace root        12365 Apr 24 13:07 google_colab_install_conda.ipynb
# -rw-rw-rw-  1 codespace root       126003 Apr 24 13:07 google_colab_r_magic_command.ipynb
# -rw-rw-rw-  1 codespace root       367900 Apr 24 13:07 google_colab_r_notebook.ipynb
# -rw-rw-rw-  1 codespace root        64520 Apr 24 13:07 hyperparameter_tuning.ipynb
# drwxrwxrwx+ 2 codespace root         4096 Apr 24 13:07 iris
# -rw-rw-rw-  1 codespace root      1389624 Apr 24 13:07 klib.ipynb
# -rw-rw-rw-  1 codespace root        94044 Apr 24 13:07 linear_regression.ipynb
# -rw-rw-rw-  1 codespace root         4781 Apr 24 13:07 model_is_training_progress_bar.ipynb
# -rw-rw-rw-  1 codespace root        37677 Apr 24 13:07 pandas-create-and-combine-dataframes.ipynb
# -rw-rw-rw-  1 codespace root      5099011 Apr 24 13:07 pandas_exploratory_data_analysis.ipynb
# -rw-rw-rw-  1 codespace root      3012732 Apr 24 13:07 pandas_profiling_example.ipynb
# -rw-rw-rw-  1 codespace root        87980 Apr 24 13:07 pandas_read_html_for_webscraping.ipynb
# -rw-rw-rw-  1 codespace root        25518 Apr 24 13:07 pandas_select_columns.ipynb
# -rw-rw-rw-  1 codespace root       100669 Apr 24 13:07 pandas_styling_dataframe.ipynb
# -rw-rw-rw-  1 codespace root         5865 Apr 24 13:07 r_magic_command.ipynb

# %% [markdown]
# ---
